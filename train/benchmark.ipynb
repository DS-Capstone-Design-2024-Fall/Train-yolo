# %% [markdown]
# ### aurora : CUDA 12.2
# ### local : CUDA 12.5

# %%
from ultralytics.utils.benchmarks import benchmark

# Benchmark on GPU
# benchmark(model="yolov8n.pt", data="coco8.yaml", imgsz=640, half=False, device=0)
benchmark(
    model="./runs/detect/train20/weights/best.pt",
    data="../street-facilities.yaml",
    imgsz=640,
    half=False,
    device=0,
)
# Out:
# image 1/1 D:\anaconda3\envs\myvenv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x480 (no detections), 74.8ms
# Speed: 192.4ms preprocess, 74.8ms inference, 431.4ms postprocess per image at shape (1, 3, 640, 480)
# ERROR  Benchmark failure for PyTorch:
# Dataset '../street-facilities.yaml' images not found , missing path 'D:\dev\ML\repos\capstone-2024-fall\train\datasets\street-facilities\images\val'
# Note dataset download directory is 'D:\dev\ML\repos\capstone-2024-fall\train\datasets'. You can update this in 'C:\Users\user\AppData\Roaming\Ultralytics\settings.json'
#
# PyTorch: starting from 'runs\detect\train20\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (4.4 MB)
#
# TorchScript: starting export with torch 2.4.1...
# TorchScript: export success  4.7s, saved as 'runs\detect\train20\weights\best.torchscript' (8.8 MB)
#
# Export complete (5.0s)
# Results saved to D:\dev\ML\repos\capstone-2024-fall\train\runs\detect\train20\weights
# Predict:         yolo predict task=detect model=runs\detect\train20\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train20\weights\best.torchscript imgsz=640 data=../street-facilities.yaml
# Visualize:       https://netron.app
# Loading runs\detect\train20\weights\best.torchscript for TorchScript inference...
#
# image 1/1 D:\anaconda3\envs\myvenv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x640 (no detections), 68.7ms
# Speed: 31.9ms preprocess, 68.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Loading runs\detect\train20\weights\best.torchscript for TorchScript inference...
# ERROR  Benchmark failure for TorchScript:
# Dataset '../street-facilities.yaml' images not found , missing path 'D:\dev\ML\repos\capstone-2024-fall\train\datasets\street-facilities\images\val'
# Note dataset download directory is 'D:\dev\ML\repos\capstone-2024-fall\train\datasets'. You can update this in 'C:\Users\user\AppData\Roaming\Ultralytics\settings.json'
#
# PyTorch: starting from 'runs\detect\train20\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (4.4 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim==0.1.34', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp311-cp311-win_amd64.whl.metadata (16 kB)
# Collecting onnxslim==0.1.34
#   Downloading onnxslim-0.1.34-py3-none-any.whl.metadata (2.7 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.19.2-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: sympy in d:\anaconda3\envs\myvenv\lib\site-packages (from onnxslim==0.1.34) (1.13.2)
# Requirement already satisfied: packaging in d:\anaconda3\envs\myvenv\lib\site-packages (from onnxslim==0.1.34) (24.0)
# Requirement already satisfied: numpy>=1.20 in d:\anaconda3\envs\myvenv\lib\site-packages (from onnx>=1.12.0) (1.26.4)
# Collecting protobuf>=3.20.2 (from onnx>=1.12.0)
#   Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime-gpu)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda3\envs\myvenv\lib\site-packages (from sympy->onnxslim==0.1.34) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime-gpu)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading onnxslim-0.1.34-py3-none-any.whl (140 kB)
#    ---------------------------------------- 140.3/140.3 kB 2.8 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp311-cp311-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 14.5/14.5 MB 3.3 MB/s eta 0:00:003
# Downloading onnxruntime_gpu-1.19.2-cp311-cp311-win_amd64.whl (226.4 MB)
#    ---------------------------------------- 226.4/226.4 MB 2.8 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl (431 kB)
#    ---------------------------------------- 431.5/431.5 kB 5.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 46.0/46.0 kB 2.4 MB/s eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ---------------------------------------- 83.2/83.2 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, pyreadline3, protobuf, onnx, humanfriendly, onnxslim, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 flatbuffers-24.3.25 humanfriendly-10.0 onnx-1.17.0 onnxruntime-gpu-1.19.2 onnxslim-0.1.34 protobuf-5.28.3 pyreadline3-3.5.4
#
# requirements: AutoUpdate success  128.8s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim==0.1.34', 'onnxruntime-gpu']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: export success  131.5s, saved as 'runs\detect\train20\weights\best.onnx' (8.6 MB)
#
# Export complete (131.6s)
# Results saved to D:\dev\ML\repos\capstone-2024-fall\train\runs\detect\train20\weights
# Predict:         yolo predict task=detect model=runs\detect\train20\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train20\weights\best.onnx imgsz=640 data=../street-facilities.yaml
# Visualize:       https://netron.app
# Loading runs\detect\train20\weights\best.onnx for ONNX Runtime inference...
#
# image 1/1 D:\anaconda3\envs\myvenv\Lib\site-packages\ultralytics\assets\bus.jpg: 640x640 (no detections), 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Loading runs\detect\train20\weights\best.onnx for ONNX Runtime inference...
# Setting batch=1 input of shape (1, 3, 640, 640)
# ERROR  Benchmark failure for ONNX:
# Dataset '../street-facilities.yaml' images not found , missing path 'D:\dev\ML\repos\capstone-2024-fall\train\datasets\street-facilities\images\val'
# Note dataset download directory is 'D:\dev\ML\repos\capstone-2024-fall\train\datasets'. You can update this in 'C:\Users\user\AppData\Roaming\Ultralytics\settings.json'
# ERROR  Benchmark failure for OpenVINO: inference not supported on GPU
#
# PyTorch: starting from 'runs\detect\train20\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (4.4 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.34...
# ONNX: export success  1.4s, saved as 'runs\detect\train20\weights\best.onnx' (8.6 MB)
# TensorRT: export failure  1.4s: No module named 'tensorrt'
# ERROR  Benchmark failure for TensorRT: No module named 'tensorrt'
# ERROR  Benchmark failure for CoreML: CoreML and TF.js export only supported on macOS and Linux
#
# PyTorch: starting from 'runs\detect\train20\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (4.4 MB)
# requirements: Ultralytics requirement ['tensorflow>=2.0.0'] not found, attempting AutoUpdate...
